# %% [markdown]
# # Data Exploration

# %% [markdown]
# Hey! During this first step, please, take a look at the data set and just explore it, find the types of each column and try to find interesting things. Don't worry about data cleaning. Just exploration for now.
# You can answer the following questions:
# - How many columns there are
# - The type of each column
# - The different values that a column can take
# - Which do you think are the most important columns? If we are looking at the overall score.
#
# Go wild! (Remember, so far, only exploration).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Saber_11__2019-2.csv')
# CSV file found in the link https://www.datos.gov.co/Educaci-n/PUNTAJE-ICFES-POR-DEPARTAMENTOS/x9vi-iv8c
df.head()
# Out:
# C:\Users\jsarmiento\AppData\Local\Temp\ipykernel_10276\2933275140.py:1: DtypeWarning: Columns (76,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Saber_11__2019-2.csv')
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                 TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                 TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                 TI          COLOMBIA           M  02/05/2002 12:00:00 AM
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2    20194  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3    20194  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
# 4    20194  SB11201940280831      ESTUDIANTE              No         COLOMBIA
#
#   ESTU_ETNIA  ... PUNT_INGLES PERCENTIL_INGLES DESEMP_INGLES PUNT_GLOBAL  \
# 0          -  ...        54.0               67            A1         208
# 1          -  ...        63.0               88            A2         299
# 2          -  ...        64.0               89            A2         299
# 3    Ninguno  ...        53.0               67            A1         309
# 4          -  ...        52.0               63            A1         288
#
#   PERCENTIL_GLOBAL ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL  \
# 0               25     50.9421557404314                 2.0
# 1               83      59.767864431576                 3.0
# 2               84     50.7642383644749                 2.0
# 3               88     45.7791353123516                 2.0
# 4               78     52.9109464277177                 3.0
#
#   ESTU_NSE_ESTABLECIMIENTO ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# 0                      2.0                 PUBLICAR                        NO
# 1                      4.0                 PUBLICAR                        NO
# 2                      3.0                 PUBLICAR  GENERACION E - GRATUIDAD
# 3                      3.0                 PUBLICAR  GENERACION E - GRATUIDAD
# 4                      3.0                 PUBLICAR                        NO
#
# [5 rows x 82 columns]

# %% [markdown]
# df.info to see the type of data in each column and to know if there are missing values in the dataset:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546212 entries, 0 to 546211
# Data columns (total 82 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ESTU_TIPODOCUMENTO             546212 non-null  object
#  1   ESTU_NACIONALIDAD              546212 non-null  object
#  2   ESTU_GENERO                    546212 non-null  object
#  3   ESTU_FECHANACIMIENTO           546212 non-null  object
#  4   PERIODO                        546212 non-null  int64
#  5   ESTU_CONSECUTIVO               546212 non-null  object
#  6   ESTU_ESTUDIANTE                546212 non-null  object
#  7   ESTU_TIENEETNIA                546212 non-null  object
#  8   ESTU_PAIS_RESIDE               546212 non-null  object
#  9   ESTU_ETNIA                     546212 non-null  object
#  10  ESTU_DEPTO_RESIDE              545835 non-null  object
#  11  ESTU_COD_RESIDE_DEPTO          546212 non-null  object
#  12  ESTU_MCPIO_RESIDE              545835 non-null  object
#  13  ESTU_COD_RESIDE_MCPIO          546212 non-null  object
#  14  FAMI_ESTRATOVIVIENDA           546186 non-null  object
#  15  FAMI_PERSONASHOGAR             537749 non-null  object
#  16  FAMI_CUARTOSHOGAR              539794 non-null  object
#  17  FAMI_EDUCACIONPADRE            537920 non-null  object
#  18  FAMI_EDUCACIONMADRE            525253 non-null  object
#  19  FAMI_TRABAJOLABORPADRE         538081 non-null  object
#  20  FAMI_TRABAJOLABORMADRE         538743 non-null  object
#  21  FAMI_TIENEINTERNET             537875 non-null  object
#  22  FAMI_TIENESERVICIOTV           523932 non-null  object
#  23  FAMI_TIENECOMPUTADOR           538027 non-null  object
#  24  FAMI_TIENELAVADORA             538569 non-null  object
#  25  FAMI_TIENEHORNOMICROOGAS       537582 non-null  object
#  26  FAMI_TIENEAUTOMOVIL            538006 non-null  object
#  27  FAMI_TIENEMOTOCICLETA          537395 non-null  object
#  28  FAMI_TIENECONSOLAVIDEOJUEGOS   538487 non-null  object
#  29  FAMI_NUMLIBROS                 537558 non-null  object
#  30  FAMI_COMELECHEDERIVADOS        523907 non-null  object
#  31  FAMI_COMECARNEPESCADOHUEVO     536587 non-null  object
#  32  FAMI_COMECEREALFRUTOSLEGUMBRE  523880 non-null  object
#  33  FAMI_SITUACIONECONOMICA        537953 non-null  object
#  34  ESTU_DEDICACIONLECTURADIARIA   545585 non-null  object
#  35  ESTU_DEDICACIONINTERNET        515914 non-null  object
#  36  ESTU_HORASSEMANATRABAJA        545831 non-null  object
#  37  ESTU_TIPOREMUNERACION          530704 non-null  object
#  38  COLE_CODIGO_ICFES              546212 non-null  int64
#  39  COLE_COD_DANE_ESTABLECIMIENTO  546212 non-null  int64
#  40  COLE_NOMBRE_ESTABLECIMIENTO    546212 non-null  object
#  41  COLE_GENERO                    546212 non-null  object
#  42  COLE_NATURALEZA                546212 non-null  object
#  43  COLE_CALENDARIO                546212 non-null  object
#  44  COLE_BILINGUE                  546212 non-null  object
#  45  COLE_CARACTER                  532464 non-null  object
#  46  COLE_COD_DANE_SEDE             546212 non-null  int64
#  47  COLE_NOMBRE_SEDE               546212 non-null  object
#  48  COLE_SEDE_PRINCIPAL            546212 non-null  object
#  49  COLE_AREA_UBICACION            546212 non-null  object
#  50  COLE_JORNADA                   546212 non-null  object
#  51  COLE_COD_MCPIO_UBICACION       546212 non-null  int64
#  52  COLE_MCPIO_UBICACION           546212 non-null  object
#  53  COLE_COD_DEPTO_UBICACION       546212 non-null  int64
#  54  COLE_DEPTO_UBICACION           546212 non-null  object
#  55  ESTU_PRIVADO_LIBERTAD          546212 non-null  object
#  56  ESTU_COD_MCPIO_PRESENTACION    546212 non-null  int64
#  57  ESTU_MCPIO_PRESENTACION        546212 non-null  object
#  58  ESTU_DEPTO_PRESENTACION        546212 non-null  object
#  59  ESTU_COD_DEPTO_PRESENTACION    546212 non-null  int64
#  60  PUNT_LECTURA_CRITICA           546212 non-null  int64
#  61  PERCENTIL_LECTURA_CRITICA      546212 non-null  int64
#  62  DESEMP_LECTURA_CRITICA         546212 non-null  int64
#  63  PUNT_MATEMATICAS               546212 non-null  int64
#  64  PERCENTIL_MATEMATICAS          546212 non-null  int64
#  65  DESEMP_MATEMATICAS             546212 non-null  int64
#  66  PUNT_C_NATURALES               546212 non-null  int64
#  67  PERCENTIL_C_NATURALES          546212 non-null  int64
#  68  DESEMP_C_NATURALES             546212 non-null  int64
#  69  PUNT_SOCIALES_CIUDADANAS       546212 non-null  int64
#  70  PERCENTIL_SOCIALES_CIUDADANAS  546212 non-null  int64
#  71  DESEMP_SOCIALES_CIUDADANAS     546212 non-null  int64
#  72  PUNT_INGLES                    546193 non-null  float64
#  73  PERCENTIL_INGLES               546212 non-null  int64
#  74  DESEMP_INGLES                  546212 non-null  object
#  75  PUNT_GLOBAL                    546212 non-null  int64
#  76  PERCENTIL_GLOBAL               546212 non-null  object
#  77  ESTU_INSE_INDIVIDUAL           546208 non-null  object
#  78  ESTU_NSE_INDIVIDUAL            529171 non-null  object
#  79  ESTU_NSE_ESTABLECIMIENTO       546168 non-null  float64
#  80  ESTU_ESTADOINVESTIGACION       546212 non-null  object
#  81  ESTU_GENERACION-E              546212 non-null  object
# dtypes: float64(2), int64(22), object(58)
# memory usage: 341.7+ MB

# %% [markdown]
# Extract column names in order to review data in the dataset:

# %%
col_list=list(df.columns)
len(col_list)
# Out:
# 82

# %%
df[col_list[:10]].head()

# %%
df[col_list[10:30]].head()

# %%
df[col_list[30:50]].head()

# %%
df[col_list[50:70]].head()
# Out:
#   COLE_JORNADA  COLE_COD_MCPIO_UBICACION COLE_MCPIO_UBICACION  \
# 0       MAÑANA                     47707            SANTA ANA
# 1     COMPLETA                     11001          BOGOTÁ D.C.
# 2       MAÑANA                     13001  CARTAGENA DE INDIAS
# 3       MAÑANA                     11001          BOGOTÁ D.C.
# 4       MAÑANA                     11001          BOGOTÁ D.C.
#
#    COLE_COD_DEPTO_UBICACION COLE_DEPTO_UBICACION ESTU_PRIVADO_LIBERTAD  \
# 0                        47            MAGDALENA                     N
# 1                        11               BOGOTÁ                     N
# 2                        13              BOLIVAR                     N
# 3                        11               BOGOTÁ                     N
# 4                        11               BOGOTÁ                     N
#
#    ESTU_COD_MCPIO_PRESENTACION ESTU_MCPIO_PRESENTACION  \
# 0                        47707               SANTA ANA
# 1                        11001             BOGOTÁ D.C.
# 2                        13001     CARTAGENA DE INDIAS
# 3                        11001             BOGOTÁ D.C.
# 4                        11001             BOGOTÁ D.C.
#
#   ESTU_DEPTO_PRESENTACION  ESTU_COD_DEPTO_PRESENTACION  PUNT_LECTURA_CRITICA  \
# 0               MAGDALENA                           47                    47
# 1                  BOGOTÁ                           11                    60
# 2                 BOLIVAR                           13                    66
# 3                  BOGOTÁ                           11                    62
# 4                  BOGOTÁ                           11                    63
#
#    PERCENTIL_LECTURA_CRITICA  DESEMP_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# 0                         33                       2                48
# 1                         76                       3                65
# 2                         91                       4                57
# 3                         81                       3                54
# 4                         85                       3                57
#
#    PERCENTIL_MATEMATICAS  DESEMP_MATEMATICAS  PUNT_C_NATURALES  \
# 0                     42                   2                37
# 1                     88                   3                54
# 2                     70                   3                41
# 3                     60                   3                61
# 4                     70                   3                55
#
#    PERCENTIL_C_NATURALES  DESEMP_C_NATURALES  PUNT_SOCIALES_CIUDADANAS
# 0                     15                   1                        30
# 1                     71                   2                        59
# 2                     29                   2                        74
# 3                     87                   3                        73
# 4                     74                   2                        57

# %% [markdown]
# Unique values on categorical data:

# %%
df_copy=df.copy()
df_copy.drop(["PERCENTIL_GLOBAL","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO"],axis=1,inplace=True)
df_copy=df_copy.select_dtypes(include=['object'])
uniques=df_copy.apply(lambda col: col.unique())
uniques.to_csv("IcfesUniques.csv",sep=",",index=True,header=False)

# %%
uniques
# Out:
# ESTU_TIPODOCUMENTO                     [TI, CC, PEP, CE, NES, PE, CR, CCB, PC, RC]
# ESTU_NACIONALIDAD                [COLOMBIA, VENEZUELA, ESPAÑA, ECUADOR, CROACIA...
# ESTU_GENERO                                                              [M, F, -]
# ESTU_FECHANACIMIENTO             [02/18/2002 12:00:00 AM, 06/28/2003 12:00:00 A...
# ESTU_CONSECUTIVO                 [SB11201940031558, SB11201940303339, SB1120194...
# ESTU_ESTUDIANTE                                                       [ESTUDIANTE]
# ESTU_TIENEETNIA                                                        [No, Si, -]
# ESTU_PAIS_RESIDE                 [COLOMBIA, VENEZUELA, ESPAÑA, ECUADOR, CROACIA...
# ESTU_ETNIA                       [-, Ninguno, Comunidad afrodescendiente, Paez,...
# ESTU_DEPTO_RESIDE                [MAGDALENA, BOGOTÁ, BOLIVAR, ATLANTICO, VALLE,...
# ESTU_MCPIO_RESIDE                [SANTA ANA, BOGOTÁ D.C., CARTAGENA DE INDIAS, ...
# FAMI_ESTRATOVIVIENDA             [Estrato 3, Estrato 1, -, Estrato 4, Estrato 2...
# FAMI_PERSONASHOGAR                   [5 a 6, 9 o más, 3 a 4, 7 a 8, -, nan, 1 a 2]
# FAMI_CUARTOSHOGAR                [Cinco, Tres, Dos, Cuatro, nan, Uno, -, Seis o...
# FAMI_EDUCACIONPADRE              [Educación profesional completa, Técnica o tec...
# FAMI_EDUCACIONMADRE              [Secundaria (Bachillerato) completa, Técnica o...
# FAMI_TRABAJOLABORPADRE           [No aplica, Trabaja por cuenta propia (por eje...
# FAMI_TRABAJOLABORMADRE           [Trabaja en el hogar, no trabaja o estudia, Es...
# FAMI_TIENEINTERNET                                                [Si, No, -, nan]
# FAMI_TIENESERVICIOTV                                              [Si, No, nan, -]
# FAMI_TIENECOMPUTADOR                                              [No, Si, -, nan]
# FAMI_TIENELAVADORA                                                [Si, No, nan, -]
# FAMI_TIENEHORNOMICROOGAS                                          [Si, No, -, nan]
# FAMI_TIENEAUTOMOVIL                                               [No, Si, nan, -]
# FAMI_TIENEMOTOCICLETA                                             [No, Si, -, nan]
# FAMI_TIENECONSOLAVIDEOJUEGOS                                      [No, Si, nan, -]
# FAMI_NUMLIBROS                   [MÁS DE 100 LIBROS, 26 A 100 LIBROS, 11 A 25 L...
# FAMI_COMELECHEDERIVADOS          [1 o 2 veces por semana, Todos o casi todos lo...
# FAMI_COMECARNEPESCADOHUEVO       [3 a 5 veces por semana, Todos o casi todos lo...
# FAMI_COMECEREALFRUTOSLEGUMBRE    [Nunca o rara vez comemos eso, 1 o 2 veces por...
# FAMI_SITUACIONECONOMICA                               [Peor, Mejor, Igual, -, nan]
# ESTU_DEDICACIONLECTURADIARIA     [Entre 30 y 60 minutos, 30 minutos o menos, No...
# ESTU_DEDICACIONINTERNET          [Entre 30 y 60 minutos, Más de 3 horas, nan, E...
# ESTU_HORASSEMANATRABAJA          [Menos de 10 horas, 0, Más de 30 horas, -, Ent...
# ESTU_TIPOREMUNERACION            [Si, en efectivo, No, Si, en efectivo y especi...
# COLE_NOMBRE_ESTABLECIMIENTO      [INSTITUCION EDUCATIVA DEPARTAMENTAL ANTONIO B...
# COLE_GENERO                                           [MIXTO, MASCULINO, FEMENINO]
# COLE_NATURALEZA                                              [OFICIAL, NO OFICIAL]
# COLE_CALENDARIO                                                       [A, OTRO, B]
# COLE_BILINGUE                                                            [N, -, S]
# COLE_CARACTER                    [TÉCNICO/ACADÉMICO, ACADÉMICO, nan, TÉCNICO, N...
# COLE_NOMBRE_SEDE                 [COL DPTAL ANTONIO BRUGES CARMONA, GIMN SAN AN...
# COLE_SEDE_PRINCIPAL                                                         [S, N]
# COLE_AREA_UBICACION                                                [URBANO, RURAL]
# COLE_JORNADA                     [MAÑANA, COMPLETA, NOCHE, UNICA, TARDE, SABATINA]
# COLE_MCPIO_UBICACION             [SANTA ANA, BOGOTÁ D.C., CARTAGENA DE INDIAS, ...
# COLE_DEPTO_UBICACION             [MAGDALENA, BOGOTÁ, BOLIVAR, ATLANTICO, VALLE,...
# ESTU_PRIVADO_LIBERTAD                                                       [N, S]
# ESTU_MCPIO_PRESENTACION          [SANTA ANA, BOGOTÁ D.C., CARTAGENA DE INDIAS, ...
# ESTU_DEPTO_PRESENTACION          [MAGDALENA, BOGOTÁ, BOLIVAR, ATLANTICO, VALLE,...
# DESEMP_INGLES                                                 [A1, A2, A-, B1, B+]
# ESTU_INSE_INDIVIDUAL             [50.9421557404314, 59.767864431576, 50.7642383...
# ESTU_NSE_INDIVIDUAL                       [2.0, 3.0, 4.0, nan, 1.0, 3, 4, 2, 1, -]
# ESTU_ESTADOINVESTIGACION         [PUBLICAR, NO SE COMPROBO IDENTIDAD DEL EXAMIN...
# ESTU_GENERACION-E                [NO, GENERACION E - GRATUIDAD, GENERACION E - ...
# dtype: object

# %% [markdown]
# Description of numerical data from exam results

# %%
df_copy=df.copy()
df_copy["PERCENTIL_GLOBAL"]=pd.to_numeric(df_copy["PERCENTIL_GLOBAL"],errors='coerce')
df_copy[col_list[70:77]].describe()

# %% [markdown]
# Info about scores:

# %% [markdown]
# _Note: groupby doesn't give the variance/deviation of the data...._

# %% [markdown]
# By student's residency: Does the place they live in affect the score? A later question can be correlating with economic class (estrato)

# %%
df_copy=df.copy()
list_punt=["PUNT_LECTURA_CRITICA","PUNT_MATEMATICAS","PUNT_C_NATURALES", "PUNT_SOCIALES_CIUDADANAS","PUNT_INGLES","PUNT_GLOBAL"]
df_copy=df_copy[list_punt+["ESTU_DEPTO_RESIDE","COLE_DEPTO_UBICACION","ESTU_NACIONALIDAD"]]
# df_copy=df_copy[["PUNT_GLOBAL","PERCENTIL_GLOBAL","ESTU_DEPTO_RESIDE","COLE_DEPTO_UBICACION","ESTU_NACIONALIDAD"]]
# df_copy=df_copy.set_index(["ESTU_DEPTO_RESIDE","COLE_DEPTO_UBICACION","ESTU_NACIONALIDAD"])
# index=df_copy.index
#df_copy["PERCENTIL_GLOBAL"]=pd.to_numeric(df_copy["PERCENTIL_GLOBAL"],errors='coerce')
df_copy.groupby(["ESTU_DEPTO_RESIDE"],dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
# Out:
# C:\Users\jsarmiento\AppData\Local\Temp\ipykernel_10276\2597742920.py:8: FutureWarning: ['COLE_DEPTO_UBICACION', 'ESTU_NACIONALIDAD'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_copy.groupby(["ESTU_DEPTO_RESIDE"],dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
#                   PUNT_LECTURA_CRITICA                      PUNT_MATEMATICAS  \
#                                   mean        std amax amin             mean
# ESTU_DEPTO_RESIDE
# BOGOTÁ                       55.686627   9.734576  100    0        54.745108
# SANTANDER                    55.151337  10.441471  100    0        55.152632
# BOYACA                       54.127006   9.820573  100   22        55.078029
# NORTE SANTANDER              53.455162  10.178910  100    0        53.528031
# CUNDINAMARCA                 53.344154   9.828787  100    0        52.425296
# QUINDIO                      53.171451  10.381989  100    0        51.790640
# NaN                          52.599469  10.257913   78   25        52.039788
# RISARALDA                    52.971495  10.125128  100    0        51.119159
# HUILA                        52.474801  10.284113  100    0        51.728421
# META                         52.545418   9.968950  100    0        51.537153
# CASANARE                     51.727015  10.011187  100    0        51.814283
# CALDAS                       52.045624  10.229612  100   22        50.349756
# NARIÑO                       51.222623  10.550399  100    0        50.683606
# VALLE                        51.838199  10.238354  100    0        49.250336
# ANTIOQUIA                    52.093806  10.703377  100    0        49.184486
# ATLANTICO                    51.423071  10.834192  100    0        49.291401
# ARAUCA                       50.795773  10.078783  100    0        50.402798
# TOLIMA                       51.140346  10.095140  100    0        49.376080
# CESAR                        50.642663  10.297894  100    0        49.089861
# PUTUMAYO                     49.915406   9.972271   80   23        49.222525
# SUCRE                        50.238361  10.639602  100   21        48.299003
# CORDOBA                      50.261965  10.320532  100   23        48.166692
# EXTRANJERO                   50.380597   8.180110   75   31        48.462687
# CAQUETA                      49.670408   9.833455   80   23        48.518023
# SAN ANDRES                   49.599681  10.918118   79   25        45.805423
# CAUCA                        48.517954  10.159732   80    0        46.874750
# BOLIVAR                      48.871988  10.905732  100    0        46.543239
# VICHADA                      47.587174  10.491243   76   23        45.899800
# GUAVIARE                     47.787611  10.039201   79    0        46.888889
# GUAINIA                      46.347015  11.166887   76   24        46.123134
# MAGDALENA                    47.878391  10.086699  100    0        45.198593
# LA GUAJIRA                   46.876131  10.411074   81    0        44.684842
# AMAZONAS                     45.757576   9.847103   78    0        42.408485
# VAUPES                       44.745042   9.537762   80   25        42.192635
# CHOCO                        43.630266   9.951051   79    0        40.871575
#
#                                        PUNT_C_NATURALES             ...  \
#                          std amax amin             mean        std  ...
# ESTU_DEPTO_RESIDE                                                   ...
# BOGOTÁ             11.313299  100   16        51.972069  10.239894  ...
# SANTANDER          12.034342  100   16        52.056648  11.097705  ...
# BOYACA             11.079132  100   20        51.394380   9.879593  ...
# NORTE SANTANDER    11.572745  100   17        50.445396  10.531288  ...
# CUNDINAMARCA       11.081186  100   16        49.450243   9.787830  ...
# QUINDIO            12.197311  100   17        49.045554  11.014910  ...
# NaN                12.077146  100   19        48.872679  10.786355  ...
# RISARALDA          11.536209  100   17        48.904112  10.309237  ...
# HUILA              11.819935  100    0        49.579855  10.762068  ...
# META               11.213622  100   17        48.475365  10.013409  ...
# CASANARE           11.397526  100   17        48.418822   9.972733  ...
# CALDAS             11.826336  100   18        48.449727  10.481185  ...
# NARIÑO             12.291657  100   15        48.507543  11.165361  ...
# VALLE              11.461553  100    0        47.500725  10.451041  ...
# ANTIOQUIA          12.267080  100    0        46.617813  10.890813  ...
# ATLANTICO          11.857822  100   15        47.490848  10.965144  ...
# ARAUCA             11.231735  100    0        47.331944  10.104677  ...
# TOLIMA             11.295699  100   17        47.285862   9.969271  ...
# CESAR              11.560325  100   18        47.021392  10.429272  ...
# PUTUMAYO           11.173495  100   18        46.932275  10.001247  ...
# SUCRE              11.731949  100   17        47.130797  10.718016  ...
# CORDOBA            11.545567  100   17        46.986924  10.571720  ...
# EXTRANJERO          9.658575   67   18        46.895522   8.797871  ...
# CAQUETA            10.932837   83   17        45.438809   9.528782  ...
# SAN ANDRES         11.738107   81   18        43.757576  10.524515  ...
# CAUCA              11.497819  100    0        45.156724  10.084944  ...
# BOLIVAR            11.703677  100   15        44.795815  10.650649  ...
# VICHADA            11.074863   77   20        44.975952   9.300830  ...
# GUAVIARE           11.282453  100   18        43.915438   9.403296  ...
# GUAINIA            11.484061   77   23        44.440299   9.827357  ...
# MAGDALENA          10.949910  100   15        43.309497   9.613978  ...
# LA GUAJIRA         11.261710   83    0        42.981900   9.784955  ...
# AMAZONAS           10.833545   81   19        41.983030   9.071972  ...
# VAUPES              9.871749   72   20        41.413598   8.218538  ...
# CHOCO              10.686818   81    0        38.817996   8.814328  ...
#
#                   PUNT_SOCIALES_CIUDADANAS      PUNT_INGLES                    \
#                                       amax amin        mean        std   amax
# ESTU_DEPTO_RESIDE
# BOGOTÁ                                 100   16   54.351938  12.676012  100.0
# SANTANDER                              100   18   51.095709  12.577587  100.0
# BOYACA                                 100   17   50.703335  11.128368  100.0
# NORTE SANTANDER                        100   18   49.295218  11.951422  100.0
# CUNDINAMARCA                           100   18   49.969195  11.508998  100.0
# QUINDIO                                100   19   50.458658  12.393453  100.0
# NaN                                     82   22   51.721485  13.357976  100.0
# RISARALDA                              100   18   50.235234  12.331151  100.0
# HUILA                                  100   17   48.075951  11.615448  100.0
# META                                   100   18   48.119323  11.555172  100.0
# CASANARE                               100   18   47.852828  11.037941  100.0
# CALDAS                                 100   19   48.454807  11.980737  100.0
# NARIÑO                                 100   17   47.115837  11.969232  100.0
# VALLE                                  100    0   47.803571  11.862139  100.0
# ANTIOQUIA                              100    0   47.513512  13.347281  100.0
# ATLANTICO                              100    0   48.263122  12.728986  100.0
# ARAUCA                                  81    0   46.094969  11.317086  100.0
# TOLIMA                                 100   18   47.064606  11.723606  100.0
# CESAR                                  100   17   46.414583  11.682118  100.0
# PUTUMAYO                                80    0   44.782188  10.620650  100.0
# SUCRE                                   81   18   45.127504  11.321525  100.0
# CORDOBA                                100   17   45.455979  11.195408  100.0
# EXTRANJERO                              70   23   45.917910   9.711669   74.0
# CAQUETA                                 80   19   44.485862  11.008214  100.0
# SAN ANDRES                              80   19   54.577352  12.854618   85.0
# CAUCA                                  100    0   43.422085  10.676026  100.0
# BOLIVAR                                100    0   44.290147  11.944087  100.0
# VICHADA                                 76   20   42.008016   9.515150   75.0
# GUAVIARE                                78   18   41.727630   9.890421   78.0
# GUAINIA                                 71   21   44.055970   9.955361   72.0
# MAGDALENA                              100   16   42.323048  11.002343  100.0
# LA GUAJIRA                             100    0   41.753592  10.402618  100.0
# AMAZONAS                                75   20   42.686061  10.384343   82.0
# VAUPES                                  74   22   41.439093   8.094425   73.0
# CHOCO                                   80    0   39.482618   9.864546   82.0
#
#                         PUNT_GLOBAL
#                    amin        mean        std amax amin
# ESTU_DEPTO_RESIDE
# BOGOTÁ              0.0  266.450622  48.924590  477   75
# SANTANDER           0.0  264.064617  52.289760  448  101
# BOYACA             20.0  261.560461  47.310966  460  127
# NORTE SANTANDER     0.0  255.308853  49.792815  445  130
# CUNDINAMARCA        0.0  253.136341  47.097303  425   67
# QUINDIO             0.0  251.880031  51.945521  448  115
# NaN                22.0  251.090186  51.491812  381  147
# RISARALDA           0.0  250.391402  49.172104  445   80
# HUILA               0.0  250.018881  50.587856  442   21
# META                0.0  247.901300  47.463109  467  102
# CASANARE            0.0  246.739029  47.510613  410  103
# CALDAS              0.0  246.178376  49.937276  443  130
# NARIÑO              0.0  244.311306  52.061527  452   95
# VALLE               0.0  242.553830  49.024674  457    0
# ANTIOQUIA           0.0  241.928208  52.109634  473   14
# ATLANTICO           0.0  241.557693  52.018428  437   44
# ARAUCA              0.0  241.085740  47.456169  415    0
# TOLIMA              0.0  240.876384  48.206354  435   95
# CESAR              21.0  238.436502  48.878688  438   84
# PUTUMAYO            0.0  236.573307  46.578161  393  108
# SUCRE              21.0  235.894722  50.384812  450  121
# CORDOBA             0.0  235.604532  49.055169  427  125
# EXTRANJERO         24.0  235.164179  38.155636  317  145
# CAQUETA             0.0  233.480250  45.742857  377  134
# SAN ANDRES         23.0  230.035088  49.501044  387  131
# CAUCA               0.0  228.094707  47.561819  407    0
# BOLIVAR             0.0  227.533886  50.678108  475   88
# VICHADA            23.0  225.070140  45.584348  356  122
# GUAVIARE           20.0  224.022616  44.799537  392  125
# GUAINIA            24.0  222.988806  48.572158  360  137
# MAGDALENA           0.0  221.329885  45.752676  425   46
# LA GUAJIRA          0.0  218.125679  46.617786  419   11
# AMAZONAS           22.0  213.061818  44.327963  361  100
# VAUPES             23.0  209.560907  40.162487  353  138
# CHOCO               0.0  200.808793  42.722574  380   55
#
# [35 rows x 24 columns]

# %% [markdown]
# Scores by school Location: Does the school location affect the scores?

# %%
df_copy.groupby(["COLE_DEPTO_UBICACION"],dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
# Out:
# C:\Users\jsarmiento\AppData\Local\Temp\ipykernel_10276\1808160493.py:1: FutureWarning: ['ESTU_DEPTO_RESIDE', 'ESTU_NACIONALIDAD'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_copy.groupby(["COLE_DEPTO_UBICACION"],dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
#                      PUNT_LECTURA_CRITICA                       \
#                                      mean        std amax amin
# COLE_DEPTO_UBICACION
# BOGOTÁ                          55.586802   9.718954  100    0
# SANTANDER                       55.071997  10.475641  100    0
# BOYACA                          54.169206   9.812678  100   22
# NORTE SANTANDER                 53.422111  10.171108  100    0
# CUNDINAMARCA                    53.551594   9.927003  100    0
# QUINDIO                         53.173220  10.395799  100    0
# RISARALDA                       52.992922  10.127951  100    0
# HUILA                           52.479136  10.285601  100    0
# META                            52.560166   9.979556  100    0
# CASANARE                        51.787420  10.005880  100    0
# CALDAS                          52.030192  10.227895  100   22
# NARIÑO                          51.242958  10.540127  100    0
# VALLE                           51.867008  10.241925  100    0
# ANTIOQUIA                       52.111536  10.697536  100    0
# ATLANTICO                       51.398108  10.844799  100    0
# ARAUCA                          50.812818  10.083326  100    0
# TOLIMA                          51.127433  10.079298  100   23
# CESAR                           50.641522  10.298747  100    0
# PUTUMAYO                        49.935596   9.968300   80   23
# SUCRE                           50.232254  10.642859  100   21
# CORDOBA                         50.275420  10.322479  100   23
# CAQUETA                         49.603770   9.850108   80   23
# SAN ANDRES                      49.674194  10.926261   79   25
# CAUCA                           48.510879  10.152954   80    0
# BOLIVAR                         48.897159  10.895479  100    0
# VICHADA                         47.623742  10.490649   76   23
# GUAVIARE                        47.789733  10.041624   79    0
# GUAINIA                         46.313433  11.178442   76   24
# MAGDALENA                       47.878254  10.077872  100    0
# LA GUAJIRA                      46.873118  10.407765   81    0
# AMAZONAS                        45.729040   9.835049   78    0
# VAUPES                          44.761364   9.546401   80   25
# CHOCO                           43.621050   9.931213   79    0
#
#                      PUNT_MATEMATICAS                      PUNT_C_NATURALES  \
#                                  mean        std amax amin             mean
# COLE_DEPTO_UBICACION
# BOGOTÁ                      54.613664  11.287702  100   16        51.844118
# SANTANDER                   55.047454  12.086247  100   16        51.961322
# BOYACA                      55.121169  11.055225  100   20        51.436339
# NORTE SANTANDER             53.490829  11.567973  100   17        50.420854
# CUNDINAMARCA                52.701099  11.228970  100   16        49.724419
# QUINDIO                     51.797368  12.186745  100   17        49.042724
# RISARALDA                   51.146037  11.538203  100   17        48.929124
# HUILA                       51.728300  11.828637  100    0        49.586621
# META                        51.567906  11.240059  100   17        48.500160
# CASANARE                    51.887656  11.383941  100   17        48.487723
# CALDAS                      50.325552  11.816202  100   18        48.431176
# NARIÑO                      50.718715  12.268733  100   15        48.528731
# VALLE                       49.274183  11.457915  100    0        47.524493
# ANTIOQUIA                   49.207314  12.263467  100    0        46.639710
# ATLANTICO                   49.267225  11.867644  100   15        47.462820
# ARAUCA                      50.422582  11.234426  100    0        47.362384
# TOLIMA                      49.364549  11.281587  100   17        47.274636
# CESAR                       49.093670  11.552097  100   18        47.019216
# PUTUMAYO                    49.263067  11.164956  100   18        46.969284
# SUCRE                       48.300860  11.745500  100   17        47.123399
# CORDOBA                     48.178343  11.543903  100   17        47.001301
# CAQUETA                     48.411437  10.983245   83   17        45.359178
# SAN ANDRES                  45.885484  11.771167   81   18        43.793548
# CAUCA                       46.875036  11.490053  100    0        45.160106
# BOLIVAR                     46.552128  11.692032  100   15        44.804391
# VICHADA                     45.977867  11.020578   77   21        45.002012
# GUAVIARE                    46.901283  11.285556  100   18        43.907206
# GUAINIA                     46.104478  11.483431   77   23        44.481343
# MAGDALENA                   45.203092  10.944837  100   15        43.316021
# LA GUAJIRA                  44.678325  11.261981   83    0        42.973854
# AMAZONAS                    42.416768  10.845411   81   19        41.957473
# VAUPES                      42.210227   9.880258   72   20        41.420455
# CHOCO                       40.844071  10.686045   81    0        38.815962
#
#                                  ... PUNT_SOCIALES_CIUDADANAS       \
#                             std  ...                     amax amin
# COLE_DEPTO_UBICACION             ...
# BOGOTÁ                10.189594  ...                      100   16
# SANTANDER             11.128544  ...                      100   18
# BOYACA                 9.867206  ...                      100   17
# NORTE SANTANDER       10.522210  ...                      100   18
# CUNDINAMARCA          10.002076  ...                      100   18
# QUINDIO               11.015944  ...                      100   19
# RISARALDA             10.311825  ...                      100   18
# HUILA                 10.764061  ...                      100   17
# META                  10.030728  ...                      100   18
# CASANARE               9.957721  ...                      100   18
# CALDAS                10.482571  ...                      100   19
# NARIÑO                11.149244  ...                      100   17
# VALLE                 10.453938  ...                      100    0
# ANTIOQUIA             10.889967  ...                      100    0
# ATLANTICO             10.974311  ...                      100    0
# ARAUCA                10.113548  ...                       81    0
# TOLIMA                 9.958759  ...                      100   18
# CESAR                 10.423781  ...                      100   17
# PUTUMAYO              10.000870  ...                       80    0
# SUCRE                 10.731649  ...                       81   18
# CORDOBA               10.570263  ...                      100   17
# CAQUETA                9.548109  ...                       80   19
# SAN ANDRES            10.534778  ...                       80   19
# CAUCA                 10.074964  ...                      100    0
# BOLIVAR               10.635852  ...                      100    0
# VICHADA                9.307797  ...                       76   20
# GUAVIARE               9.404044  ...                       78   18
# GUAINIA                9.810738  ...                       71   21
# MAGDALENA              9.610261  ...                      100   16
# LA GUAJIRA             9.784519  ...                      100    0
# AMAZONAS               9.067838  ...                       75   20
# VAUPES                 8.229225  ...                       74   22
# CHOCO                  8.809658  ...                       80    0
#
#                      PUNT_INGLES                         PUNT_GLOBAL  \
#                             mean        std   amax  amin        mean
# COLE_DEPTO_UBICACION
# BOGOTÁ                 54.134042  12.592941  100.0   0.0  265.804170
# SANTANDER              50.995223  12.624621  100.0   0.0  263.611355
# BOYACA                 50.789747  11.153546  100.0  20.0  261.786939
# NORTE SANTANDER        49.263568  11.934117  100.0   0.0  255.144786
# CUNDINAMARCA           50.441415  11.914927  100.0   0.0  254.514589
# QUINDIO                50.485604  12.392168  100.0   0.0  251.889319
# RISARALDA              50.294775  12.376702  100.0   0.0  250.541585
# HUILA                  48.076065  11.617092  100.0   0.0  250.039099
# META                   48.168449  11.624170  100.0   0.0  248.032317
# CASANARE               47.924992  10.984939  100.0  21.0  247.070636
# CALDAS                 48.405807  11.962462  100.0   0.0  246.045722
# NARIÑO                 47.140377  11.944971  100.0   0.0  244.422430
# VALLE                  47.850921  11.883926  100.0   0.0  242.700238
# ANTIOQUIA              47.539834  13.344066  100.0   0.0  242.027271
# ATLANTICO              48.223825  12.726530  100.0   0.0  241.427455
# ARAUCA                 46.131776  11.308412  100.0   0.0  241.212938
# TOLIMA                 47.048721  11.698449  100.0   0.0  240.813074
# CESAR                  46.418237  11.675089  100.0  21.0  238.440392
# PUTUMAYO               44.808769  10.629497  100.0   0.0  236.727520
# SUCRE                  45.120015  11.328507  100.0  21.0  235.872759
# CORDOBA                45.470550  11.200327  100.0   0.0  235.678393
# CAQUETA                44.370101  11.031664  100.0   0.0  233.068751
# SAN ANDRES             54.735484  12.796570   85.0  23.0  230.400000
# CAUCA                  43.423259  10.654116  100.0   0.0  228.079946
# BOLIVAR                44.336769  11.944560  100.0   0.0  227.631836
# VICHADA                42.042254   9.512525   75.0  23.0  225.299799
# GUAVIARE               41.728529   9.869722   78.0  20.0  224.033564
# GUAINIA                44.126866   9.879363   72.0  24.0  223.003731
# MAGDALENA              42.326489  10.994332  100.0   0.0  221.346277
# LA GUAJIRA             41.747227  10.392885  100.0   0.0  218.093831
# AMAZONAS               42.674362  10.393986   82.0  22.0  212.961118
# VAUPES                 41.482955   8.063830   73.0  23.0  209.650568
# CHOCO                  39.479073   9.853976   82.0   0.0  200.730817
#
#
#                             std amax amin
# COLE_DEPTO_UBICACION
# BOGOTÁ                48.732696  477   75
# SANTANDER             52.471746  448  101
# BOYACA                47.266741  460  127
# NORTE SANTANDER       49.752151  445  130
# CUNDINAMARCA          48.047415  435   67
# QUINDIO               51.954238  448  115
# RISARALDA             49.203446  445   80
# HUILA                 50.607111  442   21
# META                  47.584620  467  102
# CASANARE              47.446306  410  103
# CALDAS                49.912840  443  130
# NARIÑO                51.974252  452   95
# VALLE                 49.052331  457    0
# ANTIOQUIA             52.098036  473   14
# ATLANTICO             52.050775  437   44
# ARAUCA                47.471298  415    0
# TOLIMA                48.143512  435  123
# CESAR                 48.854632  438   84
# PUTUMAYO              46.554928  393  108
# SUCRE                 50.437370  450  121
# CORDOBA               49.056741  427  125
# CAQUETA               45.865342  377  112
# SAN ANDRES            49.544464  387  131
# CAUCA                 47.511465  407    0
# BOLIVAR               50.609793  475   88
# VICHADA               45.529420  356  122
# GUAVIARE              44.795129  392  125
# GUAINIA               48.564139  360  137
# MAGDALENA             45.722024  425   46
# LA GUAJIRA            46.605495  419   11
# AMAZONAS              44.324214  361  100
# VAUPES                40.184263  353  138
# CHOCO                 42.685105  380   55
#
# [33 rows x 24 columns]

# %% [markdown]
# Scores by student's nationality:
# Question would be if students from outside Colombia or with a different nationality score better than colombian students

# %%
df_copy.groupby("ESTU_NACIONALIDAD",dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
# Out:
# C:\Users\jsarmiento\AppData\Local\Temp\ipykernel_10276\1313708482.py:1: FutureWarning: ['ESTU_DEPTO_RESIDE', 'COLE_DEPTO_UBICACION'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_copy.groupby("ESTU_NACIONALIDAD",dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
#                        PUNT_LECTURA_CRITICA                       \
#                                        mean        std amax amin
# ESTU_NACIONALIDAD
# TAIWAN                            67.000000        NaN   67   67
# ALEMANIA                          68.000000        NaN   68   68
# CHILE                             75.000000  21.702534  100   61
# BÉLGICA                           69.000000        NaN   69   69
# REPÚBLICA DOMINICANA              64.500000  12.020815   73   56
# CUBA                              64.333333  10.595597   72   44
# REINO UNIDO                       58.000000        NaN   58   58
# EL SALVADOR                       64.333333   9.712535   75   56
# CROACIA                           67.000000        NaN   67   67
# MÉXICO                            62.333333   8.382521   73   53
# ESPAÑA                            62.303030  10.088622   78   39
# COSTA RICA                        62.500000   4.358899   68   59
# ESTADOS UNIDOS                    60.384615   9.768203   78   35
# ARGENTINA                         64.000000   6.976150   72   55
# BRASIL                            63.200000  17.991665   77   34
# PAÍSES BAJOS - HOLANDA            53.500000   2.121320   55   52
# ITALIA                            64.000000   5.099020   71   57
# PERÚ                              58.571429   9.235026   70   46
# AFGANISTÁN                        58.000000        NaN   58   58
# BOLIVIA                           55.400000  11.081516   66   38
# ECUADOR                           57.653846  12.390133   77   30
# CURAZAO                           56.000000        NaN   56   56
# FRANCIA                           57.666667  19.218047   75   37
# PANAMÁ                            67.000000        NaN   67   67
# CHINA                             50.000000  18.384776   63   37
# COLOMBIA                          52.156271  10.536522  100    0
# COREA DEL NORTE                   49.000000  19.798990   63   35
# VENEZUELA                         51.302976  10.630664  100   25
# COMORAS                           52.333333  10.408330   64   44
# DINAMARCA                         52.000000        NaN   52   52
# ALBANIA                           44.000000        NaN   44   44
# ARUBA                             46.000000        NaN   46   46
# VANUATU                           42.000000        NaN   42   42
#
#                        PUNT_MATEMATICAS                      PUNT_C_NATURALES  \
#                                    mean        std amax amin             mean
# ESTU_NACIONALIDAD
# TAIWAN                        78.000000        NaN   78   78        62.000000
# ALEMANIA                      67.000000        NaN   67   67        69.000000
# CHILE                         64.000000  14.106736   79   51        62.000000
# BÉLGICA                       61.000000        NaN   61   61        60.000000
# REPÚBLICA DOMINICANA          74.000000   4.242641   77   71        60.500000
# CUBA                          67.333333  11.604597   83   53        61.500000
# REINO UNIDO                   76.000000        NaN   76   76        57.000000
# EL SALVADOR                   64.333333  11.372481   77   55        60.666667
# CROACIA                       62.000000        NaN   62   62        61.000000
# MÉXICO                        63.333333   6.186006   72   54        61.333333
# ESPAÑA                        61.575758  11.272284   80   23        60.303030
# COSTA RICA                    60.250000   2.629956   64   58        58.500000
# ESTADOS UNIDOS                62.596154   9.933622   78   38        58.807692
# ARGENTINA                     57.500000   8.582929   65   46        59.000000
# BRASIL                        62.600000  15.946787   76   35        55.200000
# PAÍSES BAJOS - HOLANDA        63.000000   0.000000   63   63        55.000000
# ITALIA                        54.800000   3.420526   58   49        55.800000
# PERÚ                          59.714286  10.703804   75   45        54.428571
# AFGANISTÁN                    58.000000        NaN   58   58        52.000000
# BOLIVIA                       53.800000   9.364828   65   39        56.800000
# ECUADOR                       57.153846  13.448248   80   29        53.423077
# CURAZAO                       41.000000        NaN   41   41        62.000000
# FRANCIA                       47.666667  11.718931   61   39        48.666667
# PANAMÁ                        53.000000        NaN   53   53        42.000000
# CHINA                         58.000000  21.213203   73   43        51.000000
# COLOMBIA                      50.606823  11.996647  100    0        48.235032
# COREA DEL NORTE               48.000000   8.485281   54   42        48.500000
# VENEZUELA                     48.789901  11.820256  100   15        46.625789
# COMORAS                       49.333333   8.736895   59   42        47.000000
# DINAMARCA                     42.000000        NaN   42   42        34.000000
# ALBANIA                       37.000000        NaN   37   37        50.000000
# ARUBA                         37.000000        NaN   37   37        41.000000
# VANUATU                       42.000000        NaN   42   42        31.000000
#
#                                    ... PUNT_SOCIALES_CIUDADANAS       \
#                               std  ...                     amax amin
# ESTU_NACIONALIDAD                  ...
# TAIWAN                        NaN  ...                       64   64
# ALEMANIA                      NaN  ...                       58   58
# CHILE                    8.888194  ...                       70   55
# BÉLGICA                       NaN  ...                       71   71
# REPÚBLICA DOMINICANA    12.020815  ...                       65   51
# CUBA                    12.957623  ...                       73   33
# REINO UNIDO                   NaN  ...                       58   58
# EL SALVADOR             11.239810  ...                       72   52
# CROACIA                       NaN  ...                       59   59
# MÉXICO                  10.211105  ...                       80   37
# ESPAÑA                   8.538460  ...                       81   30
# COSTA RICA              10.344080  ...                       71   49
# ESTADOS UNIDOS          10.037261  ...                       75   30
# ARGENTINA               10.677078  ...                       65   40
# BRASIL                  15.417522  ...                       73   36
# PAÍSES BAJOS - HOLANDA   1.414214  ...                       55   46
# ITALIA                   5.540758  ...                       69   40
# PERÚ                    13.986388  ...                       63   39
# AFGANISTÁN                    NaN  ...                       55   55
# BOLIVIA                  9.984989  ...                       68   32
# ECUADOR                 11.703583  ...                       74   22
# CURAZAO                       NaN  ...                       56   56
# FRANCIA                 12.503333  ...                       76   30
# PANAMÁ                        NaN  ...                       53   53
# CHINA                   24.041631  ...                       65   27
# COLOMBIA                10.762820  ...                      100    0
# COREA DEL NORTE         10.606602  ...                       62   33
# VENEZUELA               10.638026  ...                       77   20
# COMORAS                  7.211103  ...                       54   34
# DINAMARCA                     NaN  ...                       42   42
# ALBANIA                       NaN  ...                       35   35
# ARUBA                         NaN  ...                       31   31
# VANUATU                       NaN  ...                       40   40
#
#                        PUNT_INGLES                         PUNT_GLOBAL  \
#                               mean        std   amax  amin        mean
# ESTU_NACIONALIDAD
# TAIWAN                   78.000000        NaN   78.0  78.0  343.000000
# ALEMANIA                 77.000000        NaN   77.0  77.0  332.000000
# CHILE                    74.333333  23.797759  100.0  53.0  330.000000
# BÉLGICA                  64.000000        NaN   64.0  64.0  326.000000
# REPÚBLICA DOMINICANA     72.500000   0.707107   73.0  72.0  324.500000
# CUBA                     64.666667  13.808210   79.0  43.0  317.666667
# REINO UNIDO              78.000000        NaN   78.0  78.0  317.000000
# EL SALVADOR              76.333333  20.550750  100.0  63.0  316.666667
# CROACIA                  73.000000        NaN   73.0  73.0  315.000000
# MÉXICO                   57.333333  10.708252   70.0  40.0  303.666667
# ESPAÑA                   62.909091   9.550405   85.0  46.0  303.575758
# COSTA RICA               70.000000   7.615773   77.0  62.0  303.000000
# ESTADOS UNIDOS           74.403846  11.090112  100.0  49.0  302.269231
# ARGENTINA                69.000000  22.315914   84.0  36.0  298.000000
# BRASIL                   65.800000  22.286767   85.0  29.0  297.600000
# PAÍSES BAJOS - HOLANDA   81.000000   4.242641   84.0  78.0  287.500000
# ITALIA                   61.000000   8.689074   70.0  47.0  285.600000
# PERÚ                     63.428571  15.661600   86.0  44.0  282.000000
# AFGANISTÁN               56.000000        NaN   56.0  56.0  279.000000
# BOLIVIA                  50.600000  15.565989   64.0  24.0  277.200000
# ECUADOR                  59.461538  13.700309   83.0  35.0  277.192308
# CURAZAO                  59.000000        NaN   59.0  59.0  271.000000
# FRANCIA                  61.666667  15.373137   72.0  44.0  264.000000
# PANAMÁ                   42.000000        NaN   42.0  42.0  264.000000
# CHINA                    62.500000  13.435029   72.0  53.0  260.500000
# COLOMBIA                 48.412992  12.552174  100.0   0.0  246.184534
# COREA DEL NORTE          48.000000  25.455844   66.0  30.0  241.500000
# VENEZUELA                47.519387  13.278835  100.0  23.0  239.266907
# COMORAS                  40.666667  11.930353   54.0  31.0  235.666667
# DINAMARCA                35.000000        NaN   35.0  35.0  210.000000
# ALBANIA                  32.000000        NaN   32.0  32.0  204.000000
# ARUBA                    59.000000        NaN   59.0  59.0  202.000000
# VANUATU                  27.000000        NaN   27.0  27.0  189.000000
#
#
#                                std amax amin
# ESTU_NACIONALIDAD
# TAIWAN                         NaN  343  343
# ALEMANIA                       NaN  332  332
# CHILE                    68.636725  409  285
# BÉLGICA                        NaN  326  326
# REPÚBLICA DOMINICANA     34.648232  349  300
# CUBA                     58.486466  380  217
# REINO UNIDO                    NaN  317  317
# EL SALVADOR              56.092186  381  278
# CROACIA                        NaN  315  315
# MÉXICO                   41.083654  372  261
# ESPAÑA                   44.758400  383  197
# COSTA RICA               31.601688  336  274
# ESTADOS UNIDOS           44.333016  373  182
# ARGENTINA                48.442406  330  226
# BRASIL                   79.616581  377  169
# PAÍSES BAJOS - HOLANDA    6.363961  292  283
# ITALIA                   20.032474  320  270
# PERÚ                     50.036653  351  214
# AFGANISTÁN                     NaN  279  279
# BOLIVIA                  56.113278  325  181
# ECUADOR                  59.334994  368  152
# CURAZAO                        NaN  271  271
# FRANCIA                  79.000000  343  185
# PANAMÁ                         NaN  264  264
# CHINA                   109.601551  338  183
# COLOMBIA                 51.380487  477    0
# COREA DEL NORTE          78.488853  297  186
# VENEZUELA                50.489544  419  116
# COMORAS                  40.377386  282  208
# DINAMARCA                      NaN  210  210
# ALBANIA                        NaN  204  204
# ARUBA                          NaN  202  202
# VANUATU                        NaN  189  189
#
# [33 rows x 24 columns]

# %% [markdown]
# From the table above, NaN values in deviation means that the count of students of that nationality is 1:

# %%
df_copy=df.copy()
df_copy=df_copy=df_copy[["ESTU_NACIONALIDAD","PERIODO"]]
df_copy.groupby("ESTU_NACIONALIDAD").count().sort_values(by="PERIODO",ascending=False)
# Out:
#                         PERIODO
# ESTU_NACIONALIDAD
# COLOMBIA                 544918
# VENEZUELA                  1109
# ESTADOS UNIDOS               52
# ESPAÑA                       33
# ECUADOR                      26
# PERÚ                          7
# CUBA                          6
# MÉXICO                        6
# BOLIVIA                       5
# BRASIL                        5
# ITALIA                        5
# ARGENTINA                     4
# COSTA RICA                    4
# FRANCIA                       3
# EL SALVADOR                   3
# CHILE                         3
# COMORAS                       3
# CHINA                         2
# PAÍSES BAJOS - HOLANDA        2
# REPÚBLICA DOMINICANA          2
# COREA DEL NORTE               2
# TAIWAN                        1
# REINO UNIDO                   1
# PANAMÁ                        1
# VANUATU                       1
# AFGANISTÁN                    1
# DINAMARCA                     1
# ALBANIA                       1
# CROACIA                       1
# BÉLGICA                       1
# ARUBA                         1
# ALEMANIA                      1
# CURAZAO                       1

# %%
list_punt=["PUNT_LECTURA_CRITICA","PUNT_MATEMATICAS","PUNT_C_NATURALES","PUNT_SOCIALES_CIUDADANAS","PUNT_INGLES","PUNT_GLOBAL"]
for dept in uniques["ESTU_DEPTO_RESIDE"]:
    df_copy=df.copy()
    df_copy=df_copy[df_copy["ESTU_DEPTO_RESIDE"].isin([dept])]  #filtered by exam topic
    # p=sns.histplot(data=df_copy[list_punt[0]],binwidth=1,alpha=0.1,kde=True)
    p=sns.kdeplot(data=df_copy[list_punt[0]])
plt.legend(uniques["ESTU_DEPTO_RESIDE"],bbox_to_anchor=(1.02,1))
plt.show()

# %% [markdown]
# looking at the plot above, plotting distributions of scores by department will be hard

# %% [markdown]
# Now, asking a similar question, but separating by genders:

# %%
list_desemp=["DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_C_NATURALES","DESEMP_SOCIALES_CIUDADANAS","DESEMP_INGLES"]
list_punt=["PUNT_LECTURA_CRITICA","PUNT_MATEMATICAS","PUNT_C_NATURALES","PUNT_SOCIALES_CIUDADANAS","PUNT_INGLES","PUNT_GLOBAL"]
df_copy=df.copy()
df_copy=df_copy[list_punt+["ESTU_GENERO"]]
df_copy.groupby(["ESTU_GENERO"],dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
# Out:
#             PUNT_LECTURA_CRITICA                      PUNT_MATEMATICAS  \
#                             mean        std amax amin             mean
# ESTU_GENERO
# M                      52.496135  10.616554  100    0        52.555788
# -                      52.958678   9.787234   75   31        51.595041
# F                      51.870687  10.462860  100    0        48.958786
#
#                                  PUNT_C_NATURALES             ...  \
#                    std amax amin             mean        std  ...
# ESTU_GENERO                                                   ...
# M            12.062005  100    0        49.386166  11.137052  ...
# -            11.599266   80   27        49.289256   9.801733  ...
# F            11.692483  100    0        47.261495  10.339375  ...
#
#             PUNT_SOCIALES_CIUDADANAS      PUNT_INGLES                          \
#                                 amax amin        mean        std   amax  amin
# ESTU_GENERO
# M                                100    0   49.004882  12.833048  100.0   0.0
# -                                 71   25   49.694215  11.564920  100.0  27.0
# F                                100    0   47.919553  12.300142  100.0   0.0
#
#             PUNT_GLOBAL
#                    mean        std amax amin
# ESTU_GENERO
# M            250.912642  52.437067  477    0
# -            250.016529  46.819331  370  162
# F            242.191565  50.138217  473    0
#
# [3 rows x 24 columns]

# %%
list_desemp=["DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_C_NATURALES","DESEMP_SOCIALES_CIUDADANAS","DESEMP_INGLES"]
list_punt=["PUNT_LECTURA_CRITICA","PUNT_MATEMATICAS","PUNT_C_NATURALES","PUNT_SOCIALES_CIUDADANAS","PUNT_INGLES","PUNT_GLOBAL"]
df_copy=df.copy()
df_copy=df_copy[df_copy["ESTU_GENERO"].isin(['M'])]  #filtered by student gender=M
p=sns.histplot(data=df_copy[list_punt[-1]],binwidth=2,alpha=0.5,kde=True)
df_copy=df.copy()
df_copy=df_copy[df_copy["ESTU_GENERO"].isin(['F'])]  #filtered by student gender=F
p=sns.histplot(data=df_copy[list_punt[-1]],binwidth=2,alpha=0.5,kde=True)
df_copy=df.copy()
df_copy=df_copy[df_copy["ESTU_GENERO"].isin(['-'])]  #filtered by student gender=not specified
p=sns.histplot(data=df_copy[list_punt[-1]],binwidth=2,alpha=0.5,kde=True)
plt.legend(uniques["ESTU_GENERO"],bbox_to_anchor=(1.02,1))
plt.title("Total score distribution by gender")
plt.show()

# %%
fig,axs=plt.subplots(2,3,figsize=(15,10),tight_layout=True)
df_copy=df.copy()
df_copy=df_copy[df_copy["ESTU_GENERO"].isin(['M'])]  #filtered by student gender=M
for i in range(2):
    for j in range(3):
        sns.histplot(data=df_copy[list_punt[3*i+j]],binwidth=2,alpha=0.5,kde=True,ax=axs[i,j],label="M")
        axs[i,j].set_label
df_copy=df.copy()
df_copy=df_copy[df_copy["ESTU_GENERO"].isin(['F'])]  #filtered by student gender=F
for i in range(2):
    for j in range(3):
        sns.histplot(data=df_copy[list_punt[3*i+j]],binwidth=2,alpha=0.5,kde=True,ax=axs[i,j],label="F")
df_copy=df.copy()
df_copy=df_copy[df_copy["ESTU_GENERO"].isin(['-'])]  #filtered by student gender=not specified
for i in range(2):
    for j in range(3):
        sns.histplot(data=df_copy[list_punt[3*i+j]],binwidth=2,alpha=0.5,kde=True,ax=axs[i,j],label="-")
Lines,Label=axs[0,1].get_legend_handles_labels()
fig.legend(Lines,Label,bbox_to_anchor=[0.5,-0.05],loc='lower center',ncol=3)
plt.suptitle("Scores Distribution by Category",fontsize='x-large')
plt.show()

# %% [markdown]
# Regarding economic class: Does economic class affect the scores?

# %%
df_copy=df.copy()
df_copy=df_copy[["FAMI_ESTRATOVIVIENDA","PERIODO"]]
df_copy.groupby("FAMI_ESTRATOVIVIENDA").count().sort_values(by="PERIODO",ascending=False)
# Out:
#                       PERIODO
# FAMI_ESTRATOVIVIENDA
# Estrato 2              188314
# Estrato 1              159977
# Estrato 3              108692
# -                       34481
# Estrato 4               25810
# Sin Estrato             17177
# Estrato 5                8024
# Estrato 6                3711

# %%
df_copy=df.copy()
p=sns.histplot(data=df_copy,x="FAMI_ESTRATOVIVIENDA")
p.set_xticklabels(labels=df_copy["FAMI_ESTRATOVIVIENDA"].unique(),rotation=90)
plt.title("Distibution of Economic Class (Estrato)")
plt.show()
# Out:
# C:\Users\jsarmiento\AppData\Local\Temp\ipykernel_10276\1169676274.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   p.set_xticklabels(labels=df_copy["FAMI_ESTRATOVIVIENDA"].unique(),rotation=90)

# %%
df_copy=df.copy()
list_punt=["PUNT_LECTURA_CRITICA","PUNT_MATEMATICAS","PUNT_C_NATURALES", "PUNT_SOCIALES_CIUDADANAS","PUNT_INGLES","PUNT_GLOBAL"]
df_copy=df_copy[list_punt+["FAMI_ESTRATOVIVIENDA"]]
df_copy.groupby(["FAMI_ESTRATOVIVIENDA"],dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
# Out:
#                      PUNT_LECTURA_CRITICA                       \
#                                      mean        std amax amin
# FAMI_ESTRATOVIVIENDA
# Estrato 4                       56.106277  12.018441  100   21
# Estrato 5                       54.925224  12.708827  100   22
# Estrato 3                       55.014362  10.387267  100    0
# Estrato 2                       52.907309   9.907123  100    0
# Estrato 6                       51.848289  13.638435  100   23
# NaN                             51.730769  10.945529   72   27
# Estrato 1                       50.261363   9.808966  100    0
# -                               48.146776  10.938552  100    0
# Sin Estrato                     44.405309   9.626249  100    0
#
#                      PUNT_MATEMATICAS                      PUNT_C_NATURALES  \
#                                  mean        std amax amin             mean
# FAMI_ESTRATOVIVIENDA
# Estrato 4                   55.174390  14.049797  100   17        52.618287
# Estrato 5                   54.112787  15.115851  100   17        51.451147
# Estrato 3                   53.708047  11.968545  100   16        51.136744
# Estrato 2                   51.469498  11.279558  100   15        48.982657
# Estrato 6                   50.546753  16.065966  100   17        48.155484
# NaN                         47.500000  10.343114   71   28        45.000000
# Estrato 1                   48.657157  11.063781  100   15        46.551736
# -                           45.142136  12.028512  100    0        42.358429
# Sin Estrato                 42.154916  10.651022  100    0        41.076731
#
#                                  ... PUNT_SOCIALES_CIUDADANAS       \
#                             std  ...                     amax amin
# FAMI_ESTRATOVIVIENDA             ...
# Estrato 4             12.817232  ...                      100    0
# Estrato 5             13.764996  ...                      100    0
# Estrato 3             10.870199  ...                      100   16
# Estrato 2             10.116560  ...                      100    0
# Estrato 6             14.420161  ...                      100   17
# NaN                   11.038116  ...                       69   28
# Estrato 1              9.759949  ...                      100    0
# -                     10.648041  ...                      100    0
# Sin Estrato            8.911140  ...                      100    0
#
#                      PUNT_INGLES                         PUNT_GLOBAL  \
#                             mean        std   amax  amin        mean
# FAMI_ESTRATOVIVIENDA
# Estrato 4              57.085936  15.976550  100.0   0.0  269.947307
# Estrato 5              56.537637  17.952368  100.0  21.0  264.737662
# Estrato 3              53.256535  12.957124  100.0   0.0  261.945240
# Estrato 2              48.891601  11.373555  100.0   0.0  249.833209
# Estrato 6              52.967125  19.275377  100.0   0.0  248.422797
# NaN                    49.115385  12.529412   78.0  27.0  238.653846
# Estrato 1              44.789062  10.277412  100.0   0.0  236.001669
# -                      42.942129  11.899456  100.0   0.0  221.313013
# Sin Estrato            39.557354   9.594040  100.0   0.0  206.434651
#
#
#                             std amax amin
# FAMI_ESTRATOVIVIENDA
# Estrato 4             62.595543  477   80
# Estrato 5             67.550098  473  123
# Estrato 3             51.963464  467   75
# Estrato 2             47.832557  460   80
# Estrato 6             72.009747  443  112
# NaN                   47.544457  328  158
# Estrato 1             45.640963  439  106
# -                     49.760803  442    0
# Sin Estrato           42.083426  418    0
#
# [9 rows x 24 columns]

# %%
df_copy=df.copy()
fig,axs=plt.subplots(2,3,figsize=(15,10),tight_layout=True)
estratos=uniques["FAMI_ESTRATOVIVIENDA"]
for estrato in estratos:
    df_copy=df.copy()
    df_copy=df_copy[df_copy["FAMI_ESTRATOVIVIENDA"].isin([estrato])]  #filtered by student gender=M
    for i in range(2):
        for j in range(3):
            sns.histplot(data=df_copy[list_punt[3*i+j]],binwidth=2,alpha=0.5,kde=True,ax=axs[i,j],label=estrato,element="step",fill=False)

Lines,Label=axs[0,1].get_legend_handles_labels()
print(Lines)
fig.legend(Lines,Label,bbox_to_anchor=[0.5,-0.05],loc='lower center',ncol=10)
plt.suptitle("Scores Distribution by Category Comparing Economic Class (Estrato)",fontsize='x-large')
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x00000249947713C0>, <matplotlib.lines.Line2D object at 0x000002498C1C4760>, <matplotlib.lines.Line2D object at 0x000002498BB60550>, <matplotlib.lines.Line2D object at 0x000002498BB626E0>, <matplotlib.lines.Line2D object at 0x000002498C1C56F0>, <matplotlib.lines.Line2D object at 0x0000024900878640>, <matplotlib.lines.Line2D object at 0x00000249005276D0>, <matplotlib.lines.Line2D object at 0x00000249931EBAC0>, <matplotlib.lines.Line2D object at 0x0000024900878EB0>]

# %% [markdown]
# Searching for my highscool results just because:

# %%
df_copy=df.copy()
df_copy=df_copy[df_copy["COLE_BILINGUE"].isin(["S"])]
df_copy=df_copy[df_copy["COLE_DEPTO_UBICACION"].isin(["CUNDINAMARCA"])]
# df_copy=df_copy[[]]
# df_copy.groupby(["COLE_NOMBRE_ESTABLECIMIENTO"],dropna=False)..sort_values([("PUNT_GLOBAL","mean")],ascending=False)
df_copy.groupby(["COLE_MCPIO_UBICACION"],dropna=False).count()
# Out:
#                       ESTU_TIPODOCUMENTO  ESTU_NACIONALIDAD  ESTU_GENERO  \
# COLE_MCPIO_UBICACION
# CHÍA                                  10                 10           10
# COTA                                  29                 29           29
# FUNZA                                 21                 21           21
# GUATAVITA                             46                 46           46
# SOACHA                                 1                  1            1
# TABIO                                 41                 41           41
#
#                       ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO  \
# COLE_MCPIO_UBICACION
# CHÍA                                    10       10                10
# COTA                                    29       29                29
# FUNZA                                   21       21                21
# GUATAVITA                               46       46                46
# SOACHA                                   1        1                 1
# TABIO                                   41       41                41
#
#                       ESTU_ESTUDIANTE  ESTU_TIENEETNIA  ESTU_PAIS_RESIDE  \
# COLE_MCPIO_UBICACION
# CHÍA                               10               10                10
# COTA                               29               29                29
# FUNZA                              21               21                21
# GUATAVITA                          46               46                46
# SOACHA                              1                1                 1
# TABIO                              41               41                41
#
#                       ESTU_ETNIA  ...  PUNT_INGLES  PERCENTIL_INGLES  \
# COLE_MCPIO_UBICACION              ...
# CHÍA                          10  ...           10                10
# COTA                          29  ...           29                29
# FUNZA                         21  ...           21                21
# GUATAVITA                     46  ...           46                46
# SOACHA                         1  ...            1                 1
# TABIO                         41  ...           41                41
#
#                       DESEMP_INGLES  PUNT_GLOBAL  PERCENTIL_GLOBAL  \
# COLE_MCPIO_UBICACION
# CHÍA                             10           10                10
# COTA                             29           29                29
# FUNZA                            21           21                21
# GUATAVITA                        46           46                46
# SOACHA                            1            1                 1
# TABIO                            41           41                41
#
#                       ESTU_INSE_INDIVIDUAL  ESTU_NSE_INDIVIDUAL  \
# COLE_MCPIO_UBICACION
# CHÍA                                    10                   10
# COTA                                    29                   26
# FUNZA                                   21                   21
# GUATAVITA                               46                   46
# SOACHA                                   1                    1
# TABIO                                   41                   41
#
#                       ESTU_NSE_ESTABLECIMIENTO  ESTU_ESTADOINVESTIGACION  \
# COLE_MCPIO_UBICACION
# CHÍA                                        10                        10
# COTA                                        29                        29
# FUNZA                                       21                        21
# GUATAVITA                                   46                        46
# SOACHA                                       1                         1
# TABIO                                       41                        41
#
#                       ESTU_GENERACION-E
# COLE_MCPIO_UBICACION
# CHÍA                                 10
# COTA                                 29
# FUNZA                                21
# GUATAVITA                            46
# SOACHA                                1
# TABIO                                41
#
# [6 rows x 81 columns]

# %%
df_copy=df.copy()
df_copy=df_copy[df_copy["COLE_BILINGUE"].isin(["S"])]
df_copy=df_copy[df_copy["COLE_DEPTO_UBICACION"].isin(["CUNDINAMARCA"])]
df_copy=df_copy[df_copy["COLE_MCPIO_UBICACION"].isin(["CHÍA"])]
df_copy=df_copy[["COLE_NOMBRE_ESTABLECIMIENTO","COLE_COD_MCPIO_UBICACION","ESTU_COD_MCPIO_PRESENTACION"]]
df_copy
# Out:
#        COLE_NOMBRE_ESTABLECIMIENTO  COLE_COD_MCPIO_UBICACION  \
# 73679       GIMNASIO OXFORD SCHOOL                     25175
# 81003       GIMNASIO OXFORD SCHOOL                     25175
# 95348       GIMNASIO OXFORD SCHOOL                     25175
# 168150      GIMNASIO OXFORD SCHOOL                     25175
# 260733      GIMNASIO OXFORD SCHOOL                     25175
# 263688      GIMNASIO OXFORD SCHOOL                     25175
# 347941      GIMNASIO OXFORD SCHOOL                     25175
# 376655      GIMNASIO OXFORD SCHOOL                     25175
# 429261      GIMNASIO OXFORD SCHOOL                     25175
# 459786      GIMNASIO OXFORD SCHOOL                     25175
#
#         ESTU_COD_MCPIO_PRESENTACION
# 73679                         11001
# 81003                         25175
# 95348                         11001
# 168150                        25175
# 260733                        25175
# 263688                        25175
# 347941                        25175
# 376655                        11001
# 429261                        25175
# 459786                        11001

# %%
df_copy=df.copy()
df_copy=df_copy[df_copy["COLE_MCPIO_UBICACION"].isin(["CHÍA"])]
df_copy=df_copy[list_punt+["ESTU_DEPTO_RESIDE"]]
df_copy.groupby(["ESTU_DEPTO_RESIDE"],dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
# Out:
#                   PUNT_LECTURA_CRITICA                      PUNT_MATEMATICAS  \
#                                   mean        std amax amin             mean
# ESTU_DEPTO_RESIDE
# BOGOTÁ                       64.000000  10.208493  100   28        65.225166
# ATLANTICO                    56.000000        NaN   56   56        55.000000
# CUNDINAMARCA                 56.539977  10.004137  100   26        55.561993
#
#                                        PUNT_C_NATURALES             ...  \
#                          std amax amin             mean        std  ...
# ESTU_DEPTO_RESIDE                                                   ...
# BOGOTÁ             10.075827  100   36        61.894040  10.637764  ...
# ATLANTICO                NaN   55   55        54.000000        NaN  ...
# CUNDINAMARCA       11.292087  100   22        52.785052  10.178103  ...
#
#                   PUNT_SOCIALES_CIUDADANAS      PUNT_INGLES                    \
#                                       amax amin        mean        std   amax
# ESTU_DEPTO_RESIDE
# BOGOTÁ                                  82   33   70.933775  12.913904  100.0
# ATLANTICO                               49   49   70.000000        NaN   70.0
# CUNDINAMARCA                           100   19   56.150637  12.729080  100.0
#
#                         PUNT_GLOBAL
#                    amin        mean        std amax amin
# ESTU_DEPTO_RESIDE
# BOGOTÁ             32.0  319.231788  48.547220  422  185
# ATLANTICO          70.0  274.000000        NaN  274  274
# CUNDINAMARCA       23.0  271.441483  49.621919  415  143
#
# [3 rows x 24 columns]

# %%
df_copy=df.copy()
df_copy=df_copy[df_copy["COLE_MCPIO_UBICACION"].isin(["CHÍA"])]
df_copy=df_copy[list_punt+["ESTU_GENERO"]]
df_copy.groupby(["ESTU_GENERO"],dropna=False).agg([np.mean,np.std,np.max,np.min]).sort_values([("PUNT_GLOBAL","mean")],ascending=False)
# Out:
#             PUNT_LECTURA_CRITICA                      PUNT_MATEMATICAS  \
#                             mean        std amax amin             mean
# ESTU_GENERO
# M                      57.665521  10.282497  100   26        58.302405
# F                      56.682587  10.146131  100   28        54.632836
#
#                                  PUNT_C_NATURALES             ...  \
#                    std amax amin             mean        std  ...
# ESTU_GENERO                                                   ...
# M            11.406087  100   22        54.814433  10.823434  ...
# F            11.309461  100   23        52.392040  10.094254  ...
#
#             PUNT_SOCIALES_CIUDADANAS      PUNT_INGLES                          \
#                                 amax amin        mean        std   amax  amin
# ESTU_GENERO
# M                                100   19   57.942726  13.289436  100.0  23.0
# F                                100   22   56.828856  13.405957  100.0  24.0
#
#             PUNT_GLOBAL
#                    mean        std amax amin
# ESTU_GENERO
# M            280.873998  51.204664  422  148
# F            270.430846  50.701439  414  143
#
# [2 rows x 24 columns]

# %%
df_copy=df.copy()
df_oxf=df_copy[df_copy["COLE_MCPIO_UBICACION"].isin(["CHÍA"])]
fig,axs=plt.subplots(2,3,figsize=(15,10),tight_layout=True)
generos=uniques["ESTU_GENERO"]
for genero in generos:
    df_copy=df_oxf[df_oxf["ESTU_GENERO"].isin([genero])]  #filtered by student gender=M
    for i in range(2):
        for j in range(3):
            sns.histplot(data=df_copy[list_punt[3*i+j]],alpha=0.5,kde=True,ax=axs[i,j],label=genero,element="step",fill=False)

Lines,Label=axs[0,1].get_legend_handles_labels()
print(Lines)
fig.legend(Lines,Label,bbox_to_anchor=[0.5,-0.05],loc='lower center',ncol=10)
plt.suptitle("GOS Scores distribution by gender",fontsize='x-large')
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x0000024992725B10>, <matplotlib.lines.Line2D object at 0x000002499277A590>]
